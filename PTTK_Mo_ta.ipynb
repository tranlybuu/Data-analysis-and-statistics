# %% [markdown]
# <a href="https://colab.research.google.com/github/tranlybuu/Project_HUET_PhanTichVaThongKeDuLieu/blob/main/PTTK_Mo_ta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Đường dẫn của file csv**

# %%
IncExpData = "https://raw.githubusercontent.com/tranlybuu/Project_HUET_PhanTichVaThongKeDuLieu/main/Inc_Exp_Data.csv"

# %% [markdown]
# **Các thư viện cần dùng**

# %%
import numpy as np
import pandas as pd
import statistics as sta
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import math
import seaborn as sns

# %% [markdown]
# **Đọc và trích xuất dữ liệu từ file csv**

# %%
data = pd.read_csv(IncExpData)
data.head(10)
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
# 5            14000              8000                  2                0
# 6            15000             16000                  3            35000
# 7            18000             20000                  5             8000
# 8            19000              9000                  2                0
# 9            20000              9000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1
# 5            196560                 Graduate                      1
# 6            167400            Post-Graduate                      1
# 7            216000                 Graduate                      1
# 8            218880           Under-Graduate                      1
# 9            220800           Under-Graduate                      2

# %% [markdown]
# **Hàm tạo bảng thống kê và vẽ Barplot**

# %%
def stat_table(a):
    x = data.groupby(a)[a].count()
    dt = pd.DataFrame(x)
    dt.columns = ['Percent']
    percent = []
    for i in dt['Percent']:
        x = (i/len(data[a]))*100
        percent.append(x)
    dt['Percent'] = percent
    print(dt)
    mylabels = dt.index
    fig = plt.figure(figsize = (5, 10))
    # Barplot
    sns.barplot(percent, mylabels, data = dt, orient = 'h')

# %% [markdown]
# **Cột Emi_or_Rent_Amt**

# %%
stat_table('Emi_or_Rent_Amt')
# Out:
#                  Percent
# Emi_or_Rent_Amt
# 0                   60.0
# 1000                 2.0
# 2000                 4.0
# 2500                 2.0
# 3000                 4.0
# 3500                 6.0
# 4000                 2.0
# 5000                 4.0
# 8000                 4.0
# 10000                4.0
# 12000                4.0
# 20000                2.0
# 35000                2.0
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Cột Highest_Qualified_Member**

# %%
stat_table('Highest_Qualified_Member')
# Out:
#                           Percent
# Highest_Qualified_Member
# Graduate                     38.0
# Illiterate                   10.0
# Post-Graduate                12.0
# Professional                 20.0
# Under-Graduate               20.0
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Cột No_of_Fly_Members**

# %%
stat_table('No_of_Fly_Members')
# Out:
#                    Percent
# No_of_Fly_Members
# 1                      2.0
# 2                     16.0
# 3                     18.0
# 4                     30.0
# 5                     10.0
# 6                     20.0
# 7                      4.0
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Cột Mthly_HH_Income**

# %%
stat_table('Mthly_HH_Income')
# Out:
#                  Percent
# Mthly_HH_Income
# 5000                 2.0
# 6000                 2.0
# 10000                4.0
# 12500                2.0
# 14000                2.0
# 15000                2.0
# 18000                2.0
# 19000                2.0
# 20000                4.0
# 22000                2.0
# 23400                2.0
# 24000                4.0
# 25000                6.0
# 29000                2.0
# 30000                2.0
# 30500                2.0
# 32000                2.0
# 34000                4.0
# 35000                4.0
# 39000                2.0
# 40000                2.0
# 42000                2.0
# 43000                2.0
# 45000                8.0
# 46000                2.0
# 47000                2.0
# 50000                2.0
# 50500                2.0
# 55000                2.0
# 60000                4.0
# 65000                2.0
# 70000                2.0
# 80000                2.0
# 85000                2.0
# 90000                2.0
# 98000                2.0
# 100000               6.0
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Cột Mthly_HH_Expense**

# %%
stat_table('Mthly_HH_Expense')
# Out:
#                   Percent
# Mthly_HH_Expense
# 2000                  2.0
# 4500                  2.0
# 5000                  2.0
# 6600                  2.0
# 7000                  2.0
# 8000                  6.0
# 9000                  6.0
# 10000                10.0
# 10500                 2.0
# 12000                 6.0
# 12300                 2.0
# 13000                 2.0
# 15000                 6.0
# 16000                 2.0
# 18000                 2.0
# 19000                 2.0
# 20000                12.0
# 22000                 2.0
# 25000                16.0
# 30000                 2.0
# 40000                 4.0
# 45000                 2.0
# 48000                 2.0
# 50000                 4.0
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Cột Annual_HH_Income**

# %%
stat_table('Annual_HH_Income')
# Out:
#                   Percent
# Annual_HH_Income
# 64200                 2.0
# 79920                 2.0
# 97200                 2.0
# 112800                2.0
# 147000                2.0
# 167400                2.0
# 196560                2.0
# 216000                2.0
# 218880                2.0
# 220800                2.0
# 244800                2.0
# 246000                2.0
# 258000                2.0
# 261000                2.0
# 278400                2.0
# 279840                2.0
# 292032                2.0
# 316800                2.0
# 330480                2.0
# 348000                2.0
# 351360                2.0
# 385200                2.0
# 412800                2.0
# 437400                2.0
# 445440                2.0
# 449400                2.0
# 456840                2.0
# 466200                2.0
# 469200                2.0
# 488880                2.0
# 507600                2.0
# 523800                2.0
# 556920                2.0
# 570000                2.0
# 581760                2.0
# 590400                4.0
# 596160                2.0
# 600600                2.0
# 610200                2.0
# 619200                2.0
# 647400                2.0
# 756000                2.0
# 885600                2.0
# 1032000               2.0
# 1075200               2.0
# 1142400               2.0
# 1152480               2.0
# 1320000               2.0
# 1404000               2.0
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Cột No_of_Earning_Members**

# %%
stat_table('No_of_Earning_Members')
# Out:
#                        Percent
# No_of_Earning_Members
# 1                         66.0
# 2                         24.0
# 3                          8.0
# 4                          2.0
# C:\Users\Admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Hàm describe để thống kê số liệu một cách đơn giản, ngắn gọn**

# %%
data.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# 25%        2.587500e+05               1.000000
# 50%        4.474200e+05               1.000000
# 75%        5.947200e+05               2.000000
# max        1.404000e+06               4.000000

# %%
NFM = data['No_of_Fly_Members']
sns.histplot(data=NFM, color = 'pink', y = NFM)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='No_of_Fly_Members'>

# %%
HQM = data['Highest_Qualified_Member']
sns.histplot(data = HQM, color = 'cyan', y = HQM)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Highest_Qualified_Member'>

# %%
NEM = data['No_of_Earning_Members']
sns.histplot(data = NEM, color = 'lime', y = NEM)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='No_of_Earning_Members'>

# %%
fig = plt.figure(figsize = (15, 8))
bp = data[['Mthly_HH_Income', 'Mthly_HH_Expense', 'Emi_or_Rent_Amt', 'Annual_HH_Income']]
sns.boxplot(data=bp, orient="h", palette="Set2")
# Out:
# <AxesSubplot:>
